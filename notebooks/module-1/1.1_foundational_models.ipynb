# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
#from langchain.chat_models import init_chat_model
#model = init_chat_model(model="gpt-5-nano")
from langchain_google_genai import ChatGoogleGenerativeAI
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
response = model.invoke("What's the capital of the Moon? Be direct and concise. Avoid all conversational filler and pleasantries!")

response
# Out:
# AIMessage(content='The Moon does not have a capital.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6827-7d96-72f2-b3c8-575c5c1b8cc0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 23, 'output_tokens': 76, 'total_tokens': 99, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 68}})

# %%
print(response.content)
# Out:
# The Moon does not have a capital.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'STOP',
#  'model_name': 'gemini-2.5-flash',
#  'model_provider': 'google_genai',
#  'safety_ratings': []}

# %% [markdown]
# ## Customising your Model

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model(
    "gemini-2.5-flash",      # Csak a modell neve stringként
    model_provider="google_genai", # A szolgáltató megjelölése
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun and imaginative question!
#
# The Moon doesn't have a capital city because it's not a country or a political entity. It's a natural satellite of Earth, and it doesn't have a government or human settlements that would establish a capital.
#
# However, if humans were to colonize the Moon in the future, they would certainly designate important locations!

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
#from langchain.agents import create_agent
#agent = create_agent(model=model)

from langchain.chat_models import init_chat_model

# Használd a google_genai providert és egy létező modellnevet
model = init_chat_model(
    "gemini-2.5-flash", 
    model_provider="google_genai"
)

agent = create_agent(model=model)

# %%
agent = create_agent(model="gemini-2.5-flash")
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# File C:\development\GitHub\langchainacademy\lca-lc-foundations\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:367, in _Config.project(self)
#     366 try:
# --> 367     self._set_project_as_env_var_or_google_auth_default()
#     368     project_id = self._project
#
# File C:\development\GitHub\langchainacademy\lca-lc-foundations\.venv\Lib\site-packages\google\cloud\aiplatform\initializer.py:114, in _Config._set_project_as_env_var_or_google_auth_default(self)
#     113 else:
# --> 114     credentials, project = google.auth.default()
#     115     self._credentials = self._credentials or credentials
#
# File C:\development\GitHub\langchainacademy\lca-lc-foundations\.venv\Lib\site-packages\google\auth\_default.py:752, in default(scopes, request, quota_project_id, default_scopes)
# ...

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='18305708-248c-4063-bfd4-52c1df0ac227'),
#               AIMessage(content="That's a fun question!\n\nThe Moon doesn't actually have a capital city. It's not a country or a political entity, so it doesn't have a government or administrative centers like a capital.\n\nPerhaps one day, if humanity establishes permanent settlements there, a capital will be named! For now, it's just a beautiful, capital-less sphere.", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019d6844-23a0-7e00-8916-2e500cd7dd62-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 10, 'output_tokens': 434, 'total_tokens': 444, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 356}})]}

# %%
print(response['messages'][-1].content)
# Out:
# Ah, Luna City! It's a fascinating concept, and while it doesn't exist in reality as an actual city today, it's a very common and well-developed idea in science fiction, speculative proposals, and even some serious architectural and engineering studies for future lunar colonization.
#
# Since we're exploring it as a concept, here's what "Luna City" often entails in these various visions:
#
# **Key Characteristics & Concepts of a Hypothetical Luna City:**
#
# 1.  **Location:**
#     *   **Polar Craters:** Often envisioned near the lunar poles (e.g., Shackleton Crater) where there are "peaks of eternal light" (constant sunlight for power) and permanently shadowed regions (PSRs) that might contain water ice, crucial for life support and rocket fuel.
#     *   **Lava Tubes:** Some concepts propose building within ancient lunar lava tubes, which would offer natural shielding from radiation, micrometeorites, and extreme temperature swings.
# ...

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='deb56b1b-37d9-40f9-905c-02e82ee634da'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='1a36cdb4-3f21-4280-a409-2a61d40daee0', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='341d82fa-ccc9-4a28-aae0-17d637ab9bc3'),
# ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City, often called "The Pearl of Selene" or simply "The Capital," is humanity's crowning achievement on the Moon. It stands as a vibrant, bustling metropolis, a testament to international cooperation, scientific ingenuity, and the enduring human spirit of exploration.
#
# Here's a detailed look at Luna City:
#
# ## Location and Layout
#
# *   **Strategic Placement:** Luna City is typically envisioned beneath the rim of a major crater, perhaps near the **Mare Imbrium** or in a region known for stable regolith and potential lava tubes, providing natural shielding from radiation and micrometeorites. Its exact coordinates might be chosen for optimal Earth visibility, access to potential resources, or proximity to scientifically interesting sites.
# *   **Multi-Level Structure:** The city is primarily subterranean, a labyrinth of interconnected tunnels, domes, and caverns carved out of the lunar bedrock.
# ...
